# %% [markdown]
#  **Data Science Jobs and Salaries Analysis** \
# By García Sady

# %% [markdown]
# *Problem description :*\
# The data explains the various job designation in data science and related salaries from across the world. \
# The main objective is to extract meaningful insight from this data in order to explain the actual remuneration each job title is providing across the globe. It will help recruiters understand the job requirements better in term of salaries across different levels of work experience so that they can get proficient profiles for any data related requirement.

# %% [markdown]
# *Approach*: \
#
#
# *   Understanding the data across relevant columns such as 'salary_in_usd'
# *   Searching for missing values to assure the accuracy of the analysis
# * Exploration of the data to gain insights such as the distribution of job titles, salaries, and work experience levels. Using summary statistics to understand the values distribution using univariate analysis, bivariate analysis and multivariate analysis
# * Visualization of the data to draw conclusions using different types of plots to visualize the categorical data vs the numerical data

# %% [markdown]
# # Data Outlook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import axes
import plotly.express as px
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore')
import plotly.io as pio

data = pd.read_csv('Pro2-data.csv')

# %%
data.shape
# Out:
# (9355, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
data.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
data.sample(5)
# Out:
#       work_year          job_title               job_category salary_currency  \
# 3687       2023       Data Analyst              Data Analysis             USD
# 1896       2023      Data Engineer           Data Engineering             USD
# 1219       2023     Data Scientist  Data Science and Research             USD
# 5252       2023      Data Engineer           Data Engineering             USD
# 455        2023  Applied Scientist  Data Science and Research             USD
#
#       salary  salary_in_usd employee_residence experience_level  \
# 3687  144100         144100      United States           Senior
# 1896  213600         213600      United States           Senior
# 1219  143000         143000      United States        Mid-level
# 5252  146000         146000      United States           Senior
# 455   260000         260000      United States           Senior
#
#      employment_type work_setting company_location company_size
# ...

# %%
data.isnull().any()
# Out:
# work_year             False
# job_title             False
# job_category          False
# salary_currency       False
# salary                False
# salary_in_usd         False
# employee_residence    False
# experience_level      False
# employment_type       False
# work_setting          False
# company_location      False
# company_size          False
# dtype: bool

# %% [markdown]
# # Univariate analysis

# %%
data.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
print('In work_year there are {} categories. The categories are :'.format(data['work_year'].value_counts().count()))
print(data['work_year'].value_counts())
# Out:
# In work_year there are 4 categories. The categories are :
# work_year
# 2023    7453
# 2022    1634
# 2021     197
# 2020      71
# Name: count, dtype: int64

# %%
J=data['job_title'].value_counts()
print('There are {} categories in total. The highest frequencies are'. format(J.count()))
print( J[0:10])
# Out:
# There are 125 categories in total. The highest frequencies are
# job_title
# Data Engineer                     2195
# Data Scientist                    1989
# Data Analyst                      1388
# Machine Learning Engineer          991
# Applied Scientist                  272
# Research Scientist                 269
# Analytics Engineer                 256
# Data Architect                     213
# Business Intelligence Engineer     144
# Research Engineer                  144
# Name: count, dtype: int64

# %%
print('In job_category there are {} categories. The categories are :'.format(data['job_category'].value_counts().count()))
print(data['job_category'].value_counts())
# Out:
# In job_category there are 10 categories. The categories are :
# job_category
# Data Science and Research         3014
# Data Engineering                  2260
# Data Analysis                     1457
# Machine Learning and AI           1428
# Leadership and Management          503
# BI and Visualization               313
# Data Architecture and Modeling     259
# Data Management and Strategy        61
# Data Quality and Operations         55
# Cloud and Database                   5
# Name: count, dtype: int64

# %%
print('In experience_level there are {} categories. The categories are :'.format(data['experience_level'].value_counts().count()))
print(data['experience_level'].value_counts())
# Out:
# In experience_level there are 4 categories. The categories are :
# experience_level
# Senior         6709
# Mid-level      1869
# Entry-level     496
# Executive       281
# Name: count, dtype: int64

# %%
print('In employment_type there are {} categories. The categories are :'.format(data['employment_type'].value_counts().count()))
print(data['employment_type'].value_counts())
# Out:
# In employment_type there are 4 categories. The categories are :
# employment_type
# Full-time    9310
# Contract       19
# Part-time      15
# Freelance      11
# Name: count, dtype: int64

# %%
print('In work_setting there are {} categories. The categories are :'.format(data['work_setting'].value_counts().count()))
print(data['work_setting'].value_counts())
# Out:
# In work_setting there are 3 categories. The categories are :
# work_setting
# In-person    5730
# Remote       3434
# Hybrid        191
# Name: count, dtype: int64

# %%
print('In company_size there are {} categories. The categories are :'.format(data['company_size'].value_counts().count()))
print(data['company_size'].value_counts())
# Out:
# In company_size there are 3 categories. The categories are :
# company_size
# M    8448
# L     748
# S     159
# Name: count, dtype: int64

# %%
print('In company_location there are', data['company_location'].value_counts().count(), 'categories. The highest frequencies are  ')
print(data['company_location'].value_counts()[0:10])
# Out:
# In company_location there are 70 categories. The highest frequencies are
# company_location
# United States     8132
# United Kingdom     449
# Canada             226
# Spain              113
# Germany             72
# France              50
# Australia           24
# Portugal            24
# Netherlands         21
# Brazil              17
# Name: count, dtype: int64

# %%
print('In employee_residence there are', data['employee_residence'].value_counts().count(), 'categories. The highest frequencies are ')
print(data['employee_residence'].value_counts()[0:10])
# Out:
# In employee_residence there are 83 categories. The highest frequencies are
# employee_residence
# United States     8086
# United Kingdom     442
# Canada             224
# Spain              117
# Germany             66
# France              54
# Portugal            26
# Netherlands         21
# Australia           21
# Italy               20
# Name: count, dtype: int64

# %%
print(data['salary_currency'].value_counts())
# Out:
# salary_currency
# USD    8591
# GBP     347
# EUR     340
# CAD      38
# AUD      11
# PLN       7
# SGD       6
# CHF       5
# BRL       4
# TRY       3
# DKK       3
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.countplot(x='work_setting',data=data,palette='muted')
plt.title('Work Setting Distribution')
plt.xlabel('Work setting')
plt.subplot(2,2,2)
sns.countplot(x='company_size',data=data,palette='pastel')
plt.title(' Company Size Distribution ')
plt.xlabel('Company size')
plt.subplot(2,2,3)
sns.countplot(x='experience_level',data=data,palette='dark', order=['Entry-level','Mid-level','Senior','Executive'])
plt.title('Experience Level Distribution')
plt.xlabel('Experience level')
plt.subplot(2,2,4)
sns.countplot(x='job_category',data=data,palette='deep')
plt.title('Job Category Distribution')
plt.xlabel('Job category')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Fig1.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(x='salary_in_usd',data=data, color='#006400',kde=True)
plt.xlabel('Salary (USD)')
plt.ylabel('Frequency')
plt.title('Salary Histogram')
plt.savefig('Fig2.jpg', bbox_inches='tight')
plt.subplot(1,2,2)
sns.boxplot(data['salary_in_usd'],color='#006400')
plt.title('Salary Mean Distribution ')
plt.ylabel('Salary (USD)')
plt.show()

# %%
cl10 = data['company_location'].value_counts().head(10)
df_cl10 = pd.DataFrame({'company_location': cl10.index, 'count': cl10.values})
fig = px.pie(df_cl10,
             values='count',
             names='company_location',
             title=' Top 10 Company Locations')
plt.savefig('Fig3.jpg', bbox_inches='tight')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
er10 = data['employee_residence'].value_counts().head(10)
df_er10 = pd.DataFrame({'employee_residence': er10.index, 'count': er10.values})
fig = px.pie(df_er10,
             values='count',
             names='employee_residence',
             title='Top 10 Employee Residence')
plt.savefig('Fig4.jpg', bbox_inches='tight')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
jt10 = data['job_title'].value_counts().head(10)
df_jt10 = pd.DataFrame({'job_title': jt10.index, 'count': jt10.values})
fig = px.pie(df_jt10,
             values='count',
             names='job_title',
             title=' Top 10 Job Titles')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='job_title',data=data,palette='deep')
plt.title('Job title distribution')
plt.xlabel('Job title')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Bivariate analysis

# %%
Year_mean = data.groupby('work_year')['salary_in_usd'].mean()
Year_std = data.groupby('work_year')['salary_in_usd'].std()
print(' Mean Salary in USD per year')
print(Year_mean)
print(' STD Salary in USD per year')
print(Year_std)
print(' Max. Salary in USD per year')
print(data.groupby('work_year')['salary_in_usd'].max())
print(' Min Salary in USD per year')
print(data.groupby('work_year')['salary_in_usd'].min())
# Out:
#  Mean Salary in USD per year
# work_year
# 2020    105878.859155
# 2021    106483.644670
# 2022    135467.501836
# 2023    155132.591708
# Name: salary_in_usd, dtype: float64
#  STD Salary in USD per year
# work_year
# 2020    83564.623808
# 2021    66944.420196
# 2022    57084.434195
# 2023    63019.147997
# Name: salary_in_usd, dtype: float64
#  Max. Salary in USD per year
# work_year
# 2020    450000
# 2021    423000
# 2022    430967
# 2023    430640
# Name: salary_in_usd, dtype: int64
#  Min Salary in USD per year
# work_year
# 2020    15000
# 2021    15000
# 2022    15000
# 2023    16000
# Name: salary_in_usd, dtype: int64

# %%
Job_title_mean = data.groupby('job_title')['salary_in_usd'].mean()
Job_title_std = data.groupby('job_title')['salary_in_usd'].std()
print(Job_title_mean.nlargest(10))
print(Job_title_mean.nsmallest(10))
# Out:
# job_title
# Analytics Engineering Manager         399880.000000
# Data Science Tech Lead                375000.000000
# Managing Director Data Science        300000.000000
# Head of Machine Learning              259000.000000
# AWS Data Architect                    258000.000000
# AI Architect                          250328.000000
# Cloud Data Architect                  250000.000000
# Director of Data Science              221365.034483
# Machine Learning Software Engineer    212907.692308
# Head of Data                          211186.545455
# Name: salary_in_usd, dtype: float64
# job_title
# Compliance Data Analyst                 45000.000
# Insight Analyst                         47673.875
# Machine Learning Specialist             55000.000
# Data Operations Specialist              55355.000
# Data Management Analyst                 56000.000
# BI Data Engineer                        60000.000
# Machine Learning Operations Engineer    60000.000
# ...

# %%
Job_category_mean = data.groupby('job_category')['salary_in_usd'].mean()
Job_category_std = data.groupby('job_category')['salary_in_usd'].std()
print(' Mean Salary in USD per Job Category')
print(Job_category_mean)
print(' STD Salary in USD per Job Category')
print(Job_category_std)
print('Max Salary per Job Category')
print(data.groupby('job_category')['salary_in_usd'].max())
print('Min Salary per Job Category')
print(data.groupby('job_category')['salary_in_usd'].min())
# Out:
#  Mean Salary in USD per Job Category
# job_category
# BI and Visualization              135092.102236
# Cloud and Database                155000.000000
# Data Analysis                     108505.721345
# Data Architecture and Modeling    156002.359073
# Data Engineering                  146197.656195
# Data Management and Strategy      103139.934426
# Data Quality and Operations       100879.472727
# Data Science and Research         163758.575979
# Leadership and Management         145476.019881
# Machine Learning and AI           178925.847339
# Name: salary_in_usd, dtype: float64
#  STD Salary in USD per Job Category
# job_category
# BI and Visualization              49280.685737
# Cloud and Database                28722.813233
# Data Analysis                     43873.075039
# Data Architecture and Modeling    57029.542685
# Data Engineering                  57116.210669
# Data Management and Strategy      44017.584652
# Data Quality and Operations       53238.033455
# ...

# %%
Employee_residence_mean = data.groupby('employee_residence')['salary_in_usd'].mean()
Employee_residence_std = data.groupby('employee_residence')['salary_in_usd'].std()

# %%
Employment_type_mean = data.groupby('employment_type')['salary_in_usd'].mean()
Employment_type_std = data.groupby('employment_type')['salary_in_usd'].std()
print(' Mean Salary in USD per employment type')
print(Employment_type_mean)
print(' STD Salary in USD per employment type')
print(Employment_type_std)
# Out:
#  Mean Salary in USD per employment type
# employment_type
# Contract     117109.368421
# Freelance     53868.636364
# Full-time    150630.092052
# Part-time     57866.066667
# Name: salary_in_usd, dtype: float64
#  STD Salary in USD per employment type
# employment_type
# Contract     107695.759793
# Freelance     26442.632631
# Full-time     62911.524086
# Part-time     40967.372817
# Name: salary_in_usd, dtype: float64

# %%
Experience_level_mean = data.groupby('experience_level')['salary_in_usd'].mean()
Experience_level_std = data.groupby('experience_level')['salary_in_usd'].std()
print('Mean Salary in USD per Experience level' )
print(Experience_level_mean)
print('STD Salary in USD per Experience level')
print(Experience_level_std)
print(data.groupby('experience_level')['salary_in_usd'].max())
print(data.groupby('experience_level')['salary_in_usd'].min())
# Out:
# Mean Salary in USD per Experience level
# experience_level
# Entry-level     88534.776210
# Executive      189462.914591
# Mid-level      117523.918138
# Senior         162356.126099
# Name: salary_in_usd, dtype: float64
# STD Salary in USD per Experience level
# experience_level
# Entry-level    49102.124930
# Executive      68792.976980
# Mid-level      55453.622208
# Senior         59523.013825
# Name: salary_in_usd, dtype: float64
# experience_level
# Entry-level    281700
# Executive      416000
# Mid-level      450000
# Senior         412000
# Name: salary_in_usd, dtype: int64
# experience_level
# Entry-level    15000
# Executive      15000
# Mid-level      15000
# Senior         18381
# Name: salary_in_usd, dtype: int64

# %%
Work_setting_mean = data.groupby('work_setting')['salary_in_usd'].mean()
Work_setting_std = data.groupby('work_setting')['salary_in_usd'].std()
print('Mean Salary in USD per Work Setting' )
print(Work_setting_mean)
print('STD Salary in USD per Work Setting')
print(Work_setting_std)
# Out:
# Mean Salary in USD per Work Setting
# work_setting
# Hybrid        88912.287958
# In-person    155524.120942
# Remote       144996.016599
# Name: salary_in_usd, dtype: float64
# STD Salary in USD per Work Setting
# work_setting
# Hybrid       62472.089654
# In-person    63891.897257
# Remote       59697.042542
# Name: salary_in_usd, dtype: float64

# %%
Company_location_mean = data.groupby('company_location')['salary_in_usd'].mean()
Company_location_std = data.groupby('company_location')['salary_in_usd'].std()
print(Company_location_mean.nlargest(10))
# Out:
# company_location
# Qatar                     300000.000000
# Puerto Rico               167500.000000
# Japan                     165500.000000
# United States             158158.728234
# Canada                    143918.836283
# Saudi Arabia              134999.000000
# Australia                 132282.708333
# New Zealand               125000.000000
# Ukraine                   121333.333333
# Bosnia and Herzegovina    120000.000000
# Name: salary_in_usd, dtype: float64

# %%
Company_size_mean = data.groupby('company_size')['salary_in_usd'].mean()
Company_size_std = data.groupby('company_size')['salary_in_usd'].std()
print('Mean Salary in USD per Company size' )
print(Company_size_mean)
print('STD Salary in USD per Company size')
print(Company_size_std)
print(data.groupby('company_size')['salary_in_usd'].max())
print(data.groupby('company_size')['salary_in_usd'].min())
# Out:
# Mean Salary in USD per Company size
# company_size
# L    141097.163102
# M    152237.089252
# S     90642.597484
# Name: salary_in_usd, dtype: float64
# STD Salary in USD per Company size
# company_size
# L    72538.573489
# M    61718.542428
# S    59942.581806
# Name: salary_in_usd, dtype: float64
# company_size
# L    423000
# M    450000
# S    416000
# Name: salary_in_usd, dtype: int64
# company_size
# L    15000
# M    15000
# S    15966
# Name: salary_in_usd, dtype: int64

# %%
Currency_mean = data.groupby('salary_currency')['salary_in_usd'].mean()
Currency_std = data.groupby('salary_currency')['salary_in_usd'].std()
print(' Mean Salary in USD per currency')
print(Currency_mean)
print(' STD Salary in USD per currency')
print(Currency_std)
# Out:
#  Mean Salary in USD per currency
# salary_currency
# AUD     78538.181818
# BRL     26168.750000
# CAD     96890.684211
# CHF    101659.400000
# DKK     31192.666667
# EUR     63738.458824
# GBP     88783.760807
# PLN     36099.428571
# SGD     81724.333333
# TRY     22189.333333
# USD    156851.450821
# Name: salary_in_usd, dtype: float64
#  STD Salary in USD per currency
# salary_currency
# AUD    27711.479238
# BRL     8958.935330
# CAD    49776.960023
# CHF    26656.735955
# DKK    13596.868475
# EUR    33782.523324
# GBP    54254.779589
# PLN    10611.082962
# SGD    20167.539718
# TRY     5124.798370
# USD    60214.172996
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='work_year',
            y ='salary_in_usd',
            data=data,
            showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Year')
plt.ylabel('Salary (USD)')
plt.title('Average Salary per Year')
plt.savefig('Fig6.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='job_title',
            y ='salary_in_usd',
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Job title')
plt.ylabel('Salary (USD)')
plt.title('Average Salary per Job Title')
plt.xticks(rotation=90)
plt.savefig('Fig7.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='job_category',
            y ='salary_in_usd',
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Job category')
plt.ylabel('Salary (USD) ')
plt.title('Average Salary per Job Category')
plt.xticks(rotation=90)
plt.savefig('Fig8.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='experience_level',
            y ='salary_in_usd',
            order=['Entry-level','Mid-level','Senior','Executive'],
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='dark')
plt.xlabel('Experience level')
plt.ylabel('Salary (USD)')
plt.title('Average Salary per Experience Level')
plt.savefig('Fig9.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='work_setting',
            y ='salary_in_usd',
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='muted')
plt.xlabel('Work setting')
plt.ylabel('Salary (USD)')
plt.title('Average Salary per Work Setting')
plt.savefig('Fig10.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='company_size',
            y ='salary_in_usd',
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='pastel')
plt.xlabel('Company size')
plt.ylabel('Salary (USD) ')
plt.title('Average Salary per Company Size')
plt.savefig('Fig11.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='employment_type',
            y ='salary_in_usd',
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'6'},
            palette='dark')
plt.xlabel('Employment type')
plt.ylabel('Salary (USD) ')
plt.title('Average Salary per Employment Type')
plt.savefig('Fig12.jpg', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='salary_currency',
            y ='salary_in_usd',
            data=data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='bright')
plt.xlabel('Currency')
plt.ylabel('Salary (USD)')
plt.title('Average Salary Across Different Currencies')
plt.savefig('Fig13.jpg', bbox_inches='tight')
plt.show()

# %%
top_job_titles = data['job_title'].value_counts().head(10).index.tolist()
plt.figure(figsize=(10, 6))
sns.boxplot(x='job_title',
            y='salary_in_usd',
            data=data[data['job_title'].isin(top_job_titles)],
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Job Title')
plt.ylabel('Salary (USD)')
plt.title('Average Salary Among Most Common Job Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('Fig14.jpg', bbox_inches='tight')
plt.show()

# %%
top_company_location = data['company_location'].value_counts().head(10).index.tolist()
plt.figure(figsize=(10, 5))
sns.boxplot(x='company_location',
            y='salary_in_usd',
            data=data[data['company_location'].isin(top_company_location)],
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='pastel')
plt.xlabel('Company location')
plt.ylabel('Salary (USD)')
plt.title('Average Salary Among Most Common Company Locations')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('Fig15.jpg', bbox_inches='tight')
plt.show()

# %%
top_residence = data['employee_residence'].value_counts().head(10).index.tolist()
plt.figure(figsize=(10, 5))
sns.boxplot(x='employee_residence',
            y='salary_in_usd',
            data=data[data['employee_residence'].isin(top_residence)],
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'6'},
            palette='colorblind')
plt.xlabel('Employee residence')
plt.ylabel('Salary (USD)')
plt.title('Average Salary Among Most Common Employee Residence')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('Fig16.jpg', bbox_inches='tight')
plt.show()

# %%
top_10_highest_salaries = Job_title_mean.nlargest(10)
bottom_10_lowest_salaries = Job_title_mean.nsmallest(10)

Higher_Sal = data[data['job_title'].isin(top_10_highest_salaries.index)]
Lower_Sal= data[data['job_title'].isin(bottom_10_lowest_salaries.index)]

plt.figure(figsize=(10, 6))
sns.boxplot(x='job_title',
            y='salary_in_usd',
            data=Higher_Sal,
             showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Job Title ')
plt.ylabel('Salary (USD)')
plt.title('Top 10 Job Titles with Highest Revenue')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Fig17.jpg', bbox_inches='tight')
plt.show()
plt.figure(figsize=(10, 6))
sns.boxplot(x='job_title',
            y='salary_in_usd',
             showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'6'},
            data=Lower_Sal,
            palette='pastel')
plt.xlabel('Job Title ')
plt.ylabel('Salary (USD)')
plt.title('Top 10 Job Titles with Lowest Revenue ')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Fig18.jpg', bbox_inches='tight')
plt.show()

# %%
Company_10 = Company_location_mean.nlargest(10)
Companies_revenue = data[data['company_location'].isin(Company_10.index)]

plt.figure(figsize=(10, 6))
sns.boxplot(x='company_location',
            y='salary_in_usd',
            data=Companies_revenue,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Company location ')
plt.ylabel('Salary (USD)')
plt.title(' Top 10 Company Locations with Highest Revenue')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Fig19.jpg', bbox_inches='tight')
plt.show()

# %%
Low_Company= Company_location_mean.nsmallest(10)
Companies_lower = data[data['company_location'].isin(Low_Company.index)]

plt.figure(figsize=(10, 5))
sns.boxplot(x='company_location',
            y='salary_in_usd',
            data=Companies_lower,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Company location ')
plt.ylabel('Salary (USD)')
plt.title('Top 10 Company Locations with Lowest Revenue')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Fig20.jpg', bbox_inches='tight')
plt.show()

# %%
top_10_res = Employee_residence_mean.nlargest(10)
Residence_revenue = data[data['employee_residence'].isin(top_10_res.index)]
plt.figure(figsize=(10, 5))
sns.boxplot(x='employee_residence',
            y='salary_in_usd',
            data= Residence_revenue,
             showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'6'},
            palette='deep')
plt.xlabel('Job Title ')
plt.ylabel('Salary (USD)')
plt.title(' Top 10 Employee Residence with Highest Revenue')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Fig21.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Multivariate analysis

# %%
fig = px.sunburst(data,
                  path=['company_size', 'work_setting', 'employment_type'],
                  values='salary_in_usd')
fig.update_layout(
    title='Sunburst Plot of Salary by Company Size, Work Setting, and Employment Type',
    title_x=0.5)
plt.savefig('Fig31.jpg', bbox_inches='tight')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(data,
                 path=['company_size', 'work_setting', 'employment_type'],
                 values='salary_in_usd')
fig.update_layout(
    title='Treemap Plot of Salary by Company Size, Work Setting, and Employment Type',
    title_x=0.5)
pio.write_html(fig, 'treemap_plot.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(data,
                 path=['experience_level', 'company_size' ,'work_setting'],
                 values='salary_in_usd')
fig.update_layout(
    title='Treemap Plot of Salary by Experience Level, Company Size and Work Setting',
    title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(data,
                 path=['company_location','employee_residence'],
                 values='salary_in_usd')
fig.update_layout(
    title='Treemap Plot of Salary by Company Location and Employee Residence',
    title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(data,
                 path=['employee_residence','company_location'],
                 values='salary_in_usd')
fig.update_layout(
    title='Treemap Plot of Salary by Employee Residence and Company Location',
    title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(data,
                 path=['company_location','work_setting'],
                 values='salary_in_usd')
fig.update_layout(
    title='Treemap Plot of Salary by Company Location and Work Setting',
    title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(data,
                 path=['work_setting','company_location'],
                 values='salary_in_usd')
fig.update_layout(
    title='Treemap Plot of Salary  by Work Setting and Company Location',
    title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
